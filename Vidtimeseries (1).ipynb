# %%
#merging files 
import pandas as pd
import glob

# Get all raw data files from folder
raw_data_files = glob.glob("/Users/naima.abdirahman/Downloads/project3data/*.csv")

# Initialize master list
master = []

# Going through every file in folder, creating and cleaning data, and appending to df
for file in raw_data_files:
    df = pd.read_csv(file)

    # Adding necessary columns
    df["filename"] = file
    df["user"] = file.split("/")[-1].split(".")[0]  # Extracting user from filename
    df["saved"] = "saved" in file.lower()

    master.append(df)

# Concatenating the files together into master dataframe
df = pd.concat(master, axis=0, ignore_index=True)

# Saving to CSV
df.to_csv("/Users/naima.abdirahman/Desktop/metadata.csv", index=False)

# %%
df.head()
# Out:
#               video_id      video_timestamp  video_duration  \
# 0  7302601347327905070  2023-11-17T20:03:14            66.0
# 1  7326753111513632043  2024-01-21T22:04:30            13.0
# 2  7325244024623746346  2024-01-17T20:28:27            11.0
# 3  7330343097244618026  2024-01-31T14:15:49            85.0
# 4  7329927237359193386  2024-01-30T11:21:56            69.0
#
#   video_locationcreated                                    suggested_words  \
# 0                    US                                                NaN
# 1                    US  yeslydimate, yesly and tony, I Look Like A Pen...
# 2                    US  yeslydimate, tony and yesly, Yesly, yesly sure...
# 3                    US                                                NaN
# 4                    US  jenna marbles, Neon Genesis Evangelion, doorkn...
#
#    video_diggcount  video_sharecount  video_commentcount  video_playcount  \
# 0          19400.0              40.0                86.0         147000.0
# 1         395800.0             525.0               259.0        3300000.0
# 2         828300.0            2128.0               750.0        7100000.0
# 3          56000.0            8358.0              1994.0        1500000.0
# 4         199900.0            2854.0              1352.0        1200000.0
#
#                                    video_description  ...  \
# 0  Talk about a humbling experience. Got a dress ...  ...
# 1                  we’ve reached full mini bob stage  ...
# 2                                                NaN  ...
# 3  #stitch with @Casey Smith If it works for you,...  ...
# 4                                       Opportunity   ...
#
#    author_followercount  author_followingcount author_heartcount  \
# 0                   NaN                    NaN               NaN
# 1                   NaN                    NaN               NaN
# 2                   NaN                    NaN               NaN
# 3                   NaN                    NaN               NaN
# 4                   NaN                    NaN               NaN
#
#   author_videocount  author_diggcount  author_verified  \
# 0               NaN               NaN            False
# 1               NaN               NaN            False
# 2               NaN               NaN            False
# 3               NaN               NaN            False
# 4               NaN               NaN            False
#
#                                             filename                user  \
# 0  /Users/naima.abdirahman/Downloads/project3data...  results_50405_full
# 1  /Users/naima.abdirahman/Downloads/project3data...  results_50405_full
# 2  /Users/naima.abdirahman/Downloads/project3data...  results_50405_full
# 3  /Users/naima.abdirahman/Downloads/project3data...  results_50405_full
# 4  /Users/naima.abdirahman/Downloads/project3data...  results_50405_full
#
#    saved  Unnamed: 0
# 0  False         NaN
# 1  False         NaN
# 2  False         NaN
# 3  False         NaN
# 4  False         NaN
#
# [5 rows x 24 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.dates as mdates
import pandas as pd

# %%
filepath="/Users/naima.abdirahman/Desktop/metadata.csv"

# %%
df=pd.read_csv(filepath)

# %%
# Filter data for years 2023 and 2024
df_23_24 = df[pd.to_datetime(df['video_timestamp']).dt.year.isin([2023, 2024])]

# Extract month from the video_timestamp
df_23_24['month'] = pd.to_datetime(df_23_24['video_timestamp']).dt.month

# Group by user and month, count videos
videos_per_month = df_23_24.groupby(['user', 'month']).size().reset_index(name='count')
# Out:
# /var/folders/2x/vtjgswgj6pj1xwzfpdt05jt40000gp/T/ipykernel_43817/1971811476.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_23_24['month'] = pd.to_datetime(df_23_24['video_timestamp']).dt.month

# %%
videos_per_month.head()
# Out:
#             user  month  count
# 0  Sec2Gr3_74721      1     18
# 1  Sec2Gr3_74721      2     18
# 2  Sec2Gr3_74721      3     29
# 3  Sec2Gr3_74721      4     16
# 4  Sec2Gr3_74721      5     22

# %%
# Extract year-month from the video_timestamp
df_23_24['year_month'] = pd.to_datetime(df_23_24['video_timestamp']).dt.to_period('M')

# Group by user and year_month, count videos
videos_per_month = df_23_24.groupby(['user', 'year_month']).size().reset_index(name='count')

# unique users
users = videos_per_month['user'].unique()
# Out:
# /var/folders/2x/vtjgswgj6pj1xwzfpdt05jt40000gp/T/ipykernel_43817/972449317.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_23_24['year_month'] = pd.to_datetime(df_23_24['video_timestamp']).dt.to_period('M')

# %%
plt.figure(figsize=(20,6))
for user in users:
    user_data = videos_per_month[videos_per_month['user'] == user]
    plt.plot(user_data['year_month'].dt.to_timestamp(), user_data['count'], label=user)

# Formatting Date on X axis
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())

# Adding labels and title
plt.xlabel('Year-Month')
plt.ylabel('Number of Videos')
plt.title('Number of Videos Per Month')

# Addng legend for dif users 
plt.legend()

#  plot 
plt.grid(True)
#save to our file 
plt.savefig("/Users/naima.abdirahman/Desktop/cs315/videos_per_month_2023_2024.png")
plt.show()

# %%
plt.show()
